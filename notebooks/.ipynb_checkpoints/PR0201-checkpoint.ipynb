# %% [markdown]
# # PR0201: Instalación y configuración de Hadoop en modo pseudo-distribuido

# %% [markdown]
# ### Datos de la maquina
# ISO: Ubuntu server
# RAM: 4GB
# Dos adaptadores de red:
# - NAT
# - Solo anfitrión
